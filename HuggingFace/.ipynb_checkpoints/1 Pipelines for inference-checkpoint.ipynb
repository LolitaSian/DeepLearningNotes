# %% [markdown]
# `pipeline()`可以让你方便地使用[model Hub](https://huggingface.co/models)
#
# `pipline()`更完整的功能可以看[pipeline文档](https://huggingface.co/docs/transformers/v4.20.1/en/main_classes/pipelines#transformers.pipeline)

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 25.3 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 23.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 45.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# 用pipeline做一个推理任务：

# %%
from transformers import pipeline
generator = pipeline(task="text-generation")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
generator(
    "Hello, Sian"
)  # doctest: +SKIP
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Hello, Sian."\n\n"No, sian… what\'s this, the fact that you spoke to me? What are these two idiots talking about, really? In any case, what do you want from us?"\n\n"We'}]

# %% [markdown]
# 还有一些参数可以选择，比如输出两个结果：

# %%
generator(
    "Hello, Sian",
    num_return_sequences=2,
)  # doctest: +SKIP
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Hello, Sian! I\'m going to have to get home later today. I\'ve been having trouble sleeping. How\'s that for a good night\'s sleep?"\n\n"You\'ve been awake for three hours. You\'ve been playing with your'},
#  {'generated_text': "Hello, Sian and all your allies there! So there, we go on to start our war against the Demon King! To do this battle, we need to use our very best martial arts skills to defeat the Demon King's Demon King Guard."}]

# %% [markdown]
# 找到你需要的模型之后加载模型。
# 使用对应的AutoModelFor和`AutoTokenizer’类去加载。
#
# [Auto Classes](https://huggingface.co/docs/transformers/v4.20.1/en/model_doc/auto#transformers.AutoModelForCausalLM)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
model = AutoModelForCausalLM.from_pretrained("distilgpt2")
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]

# %%
from transformers import pipeline
generator = pipeline(task="text-generation", model=model, tokenizer=tokenizer)
generator(
    "Hello, Sian"
)  # doctest: +SKIP
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Hello, Sian Hetzen: "The last ten. A year ago.\n\nThis article was originally published on February 19, 2010 at 2:12 pm as part of our Weekly, Weekly, and Daily Brief, a weekly column from'}]
