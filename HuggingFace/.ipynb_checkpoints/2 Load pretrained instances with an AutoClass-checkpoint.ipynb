# %% [markdown]
# <a href="https://colab.research.google.com/github/LolitaSian/DeepLearningNotes/blob/master/HuggingFace/.ipynb_checkpoints/2%20Load%20pretrained%20instances%20with%20an%20AutoClass-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HuggingFace🤗一个核心功能就是让Transformer使用更简单、灵活。
# `AutoClass`可以自动从给定的checkpoint加载对应的基于Transformer的architecture。`from_pretrained`可以让你快速加载你想要的预训练模型。
#
# > architecture指的是哪一个模型，checkpoint指的是框架的权重。比如BERT是一个框架，bert-base-uncased是checkpoint。而Model是一个通用术语，可以指architecture或者checkpoint。
#
#
# 接下来学习：
# - Load a pretrained tokenizer.
# - Load a pretrained model.

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 101 kB 10.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 40.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# # AutoTokenizer
#
# 几乎每个NLP任务都需要从tokenizer开始，它能将你的输入转化为模型可以处理的格式。使用[`AutoTokenizer.from_pretrained()`](https://huggingface.co/docs/transformers/v4.20.1/en/model_doc/auto#transformers.AutoTokenizer.from_pretrained)加载对应的tokenizer

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %% [markdown]
# 然后你的输入会转换成这样：

# %%
sequence = "Hello world."
print(tokenizer(sequence))
# Out:
# {'input_ids': [101, 7592, 2088, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1]}

# %% [markdown]
# ---
#
# # AutoModel
#
# AutoModel可以加载指定任务的预训练模型。完整功能看这里：[AutoClasses](https://huggingface.co/docs/transformers/v4.20.1/en/model_doc/auto)
#
# 通常，我们建议使用AutoTokenizer类和AutoModelFor类来加载预先训练过的模型实例。

# %%
# 分类任务
from transformers import AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained("distilbert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForTokenClassification: ['vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
